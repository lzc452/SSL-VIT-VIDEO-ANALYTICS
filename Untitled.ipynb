# %%
import gdown
from tqdm.notebook import tqdm  # Use the notebook version for nicer bars

# splits 1SUPLYwkx5WFhiJM6QeI7HDnAPoZqsPQx
# UCF101_frames 1tnhpsB1mExoWlhP9UhyMbc2fM4ovE6mR
# FaceForensics_frames 19BHJ0EGL5A4aKmdRynLJ2cSmswQ_NQ1C // 19BHJ0EGL5A4aKmdRynLJ2cSmswQ_NQ1C
# hmdb51_frames 1xSlq86xKTJBDb0VPolE1u5A9R5jV-Vxa
# Kinetics-400-Tiny_frames 1I3A8jYG-6O-QSK19RV2B8Srqv0hhDLkz
# datasets.zip 1Tp0UYnVHmhTe1GAHrULTvhLrleuglidr
# UCF101_32_frames 1Uirk4skIdNbZ7P1h0xuDooVeLEWUrz8q
url = 'https://drive.google.com/uc?id=19BHJ0EGL5A4aKmdRynLJ2cSmswQ_NQ1C'
output = 'data/FaceForensics_frames.zip' # The name you want to save it as

# Downloads the file
# --- 1. Download with Progress ---
print("Starting Download...")
# gdown has a built-in progress bar. 
# We set quiet=False to ensure it shows up.
gdown.download(url, output, quiet=False)
print("\nDownload Complete.")
# Out:
# Starting Download...
# Downloading...
# From (original): https://drive.google.com/uc?id=19BHJ0EGL5A4aKmdRynLJ2cSmswQ_NQ1C
# From (redirected): https://drive.google.com/uc?id=19BHJ0EGL5A4aKmdRynLJ2cSmswQ_NQ1C&confirm=t&uuid=9f30a5b5-6307-4018-9a3a-70802d50fabb
# To: /workspace/SSL-VIT-VIDEO-ANALYTICS/data/FaceForensics_frames.zip
# 100%|██████████| 2.34G/2.34G [00:56<00:00, 41.1MB/s]
# Download Complete.
